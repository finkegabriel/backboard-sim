# %% [markdown]
# The purpose of this paper is to recreate the work done by the youtube channel "stuff made here". Specfically on the french cleat parabolic never miss basketball hoop.

# %%
'''
First create graph with a hoop with boundry markers
'''

from matplotlib.patches import Rectangle,Circle
from graph import Graph
import matplotlib.pyplot as plt
import numpy as np
import parabolic as para
import importlib
from datetime import datetime, timedelta
import scipy.optimize as optimize
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R
import math as math
import scipy.optimize as opt

g1 = Graph()
ax = plt.axes(projection="3d")

doex = [.4,.4,.4,.4]
doey = [11,2,2,11]
doez = [9.9,9.9,15.9,15.9]

theta = 1.52
h= 0
k= 0
offset = .4

xParaBounds = 9
yParaBounds = 7

# bellow will draw points where the parabolic mesh should be top left, top right, center, bottom right, and bottom left points
ax.scatter(doex, doey, doez, color='b')
ax.scatter(doex[0],((doey[0]+doey[1])/2),((doez[0]+doez[2])/2),color='b')

guess = (1,1)
#draw hoop, arrays are for x, y location on the graph
backboard=[5,11.5]
xy=[2,10]
#hoop location parameters
circlexy=[2.25,6.5]
x = para.X(0,15)
s = para.parabolic(.3,0,12,x)

b = Rectangle(backboard,3,2.25,fill=False,color='red')
c = Circle((circlexy),radius=2.25,fill=False)
p = Rectangle(xy,9,6,edgecolor='red',facecolor='none')

g1.draw(ax,b,p,c)
plt.show()
importlib.reload(plt)
# Out:
# <module 'matplotlib.pyplot' from '/opt/homebrew/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %%
'''
now to create a boundry parabolic mesh to calculate the deflection of the ball to the center of the hoop

'''


from matplotlib.patches import Rectangle,Circle
from graph import Graph
import matplotlib.pyplot as plt
import numpy as np
import parabolic as para
import importlib
from datetime import datetime, timedelta
import scipy.optimize as optimize
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R
import math as math
import scipy.optimize as opt

g1 = Graph()
ax = plt.axes(projection="3d")

doex = [.4,.4,.4,.4]
doey = [11,2,2,11]
doez = [9.9,9.9,15.9,15.9]

theta = 1.52
h= 0
k= 0
offset = .4

xParaBounds = 9
yParaBounds = 7

# bellow will draw points where the parabolic mesh should be top left, top right, center, bottom right, and bottom left points
ax.scatter(doex, doey, doez, color='b')
ax.scatter(doex[0],((doey[0]+doey[1])/2),((doez[0]+doez[2])/2),color='b')

guess = (1,1)
#draw hoop, arrays are for x, y location on the graph
backboard=[5,11.5]
xy=[2,10]
#hoop location parameters
circlexy=[2.25,6.5]
x = para.X(0,15)
s = para.parabolic(.3,0,12,x)

b = Rectangle(backboard,3,2.25,fill=False,color='red')
c = Circle((circlexy),radius=2.25,fill=False)
p = Rectangle(xy,9,6,edgecolor='red',facecolor='none')

xi = np.linspace(-5.5, 6.5, 500)
yi = .03*xi**2
yii = (((-xi*math.cos(theta)+yi*math.sin(theta)-h)**2)+k)

ax.plot(yii+offset,-xi+((doey[0]+doey[1])/2),(doez[2]),zdir='z',color='green')

# second plot of the parabola off to the side of the hoop
xii = np.linspace(-5.5,6.5,500)
yii = .03*xii**2
yiii = (((-xi*math.cos(theta)+yi*math.sin(theta)-h)**2)+k)

xiii = np.linspace(-5.5,6.5,500)
yiiii = .03*xii**2
yiiiii = (((-xi*math.cos(theta)+yi*math.sin(theta)-h)**2)+k)


#X
ax.plot((yiiii+offset)-.5,.5*xiii+((doez[0]+doez[2])/2)-.25,((doey[1])+xParaBounds),zdir='y',color='green')
ax.plot((yiiii+offset)-.5,.5*xiii+((doez[0]+doez[2])/2)-.25,((doey[1])+(xParaBounds-9)),zdir='y',color='green')

#Y
ax.plot((yi+offset)-.5,.765*-xi+((doey[0]+doey[1])/2)+.25,(doez[2]+(yParaBounds-13)),zdir='z',color='green')
ax.plot((yii+offset)-.5,.765*-xi+((doey[0]+doey[1])/2)+.25,(doez[2]),zdir='z',color='green')


g1.draw(ax,b,p,c)
plt.show()
importlib.reload(plt)
# Out:
# <module 'matplotlib.pyplot' from '/opt/homebrew/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# Now to define "player" location, which we will handle from a fixed point just multiple trajactory's for now. Then we will try a random generator of points where the player could be in a boundry.

# %%
from matplotlib.patches import Rectangle,Circle
from graph import Graph
import matplotlib.pyplot as plt
import numpy as np
import parabolic as para
import importlib
from datetime import datetime, timedelta
import scipy.optimize as optimize
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R
import math as math
import scipy.optimize as opt

g1 = Graph()
ax = plt.axes(projection="3d")

doex = [.4,.4,.4,.4]
doey = [11,2,2,11]
doez = [9.9,9.9,15.9,15.9]

theta = 1.52
h= 0
k= 0
offset = .4

xParaBounds = 9
yParaBounds = 7

# bellow will draw points where the parabolic mesh should be top left, top right, center, bottom right, and bottom left points
ax.scatter(doex, doey, doez, color='b')
ax.scatter(doex[0],((doey[0]+doey[1])/2),((doez[0]+doez[2])/2),color='b')

guess = (1,1)
#draw hoop, arrays are for x, y location on the graph
backboard=[5,11.5]
xy=[2,10]
#hoop location parameters
circlexy=[2.25,6.5]
x = para.X(0,15)
s = para.parabolic(.3,0,12,x)

b = Rectangle(backboard,3,2.25,fill=False,color='red')
c = Circle((circlexy),radius=2.25,fill=False)
p = Rectangle(xy,9,6,edgecolor='red',facecolor='none')

xi = np.linspace(-5.5, 6.5, 500)
yi = .03*xi**2
yii = (((-xi*math.cos(theta)+yi*math.sin(theta)-h)**2)+k)

ax.plot(yii+offset,-xi+((doey[0]+doey[1])/2),(doez[2]),zdir='z',color='green')

# second plot of the parabola off to the side of the hoop
xii = np.linspace(-5.5,6.5,500)
yii = .03*xii**2
yiii = (((-xi*math.cos(theta)+yi*math.sin(theta)-h)**2)+k)

xiii = np.linspace(-5.5,6.5,500)
yiiii = .03*xii**2
yiiiii = (((-xi*math.cos(theta)+yi*math.sin(theta)-h)**2)+k)


#X
ax.plot((yiiii+offset)-.5,.5*xiii+((doez[0]+doez[2])/2)-.25,((doey[1])+xParaBounds),zdir='y',color='green')
ax.plot((yiiii+offset)-.5,.5*xiii+((doez[0]+doez[2])/2)-.25,((doey[1])+(xParaBounds-9)),zdir='y',color='green')

#Y
ax.plot((yi+offset)-.5,.765*-xi+((doey[0]+doey[1])/2)+.25,(doez[2]+(yParaBounds-13)),zdir='z',color='green')
ax.plot((yii+offset)-.5,.765*-xi+((doey[0]+doey[1])/2)+.25,(doez[2]),zdir='z',color='green')

'''
Bellow is where the player (purple dot) is defined in 3d space

'''

xip = np.linspace(0, 10, 500)
yip = .09*-xip**2+12

## player stats
playerHeight = (yip[len(yip)-1]-yip[len(yip)-1]+1.5)/2
print("height ",playerHeight)
ax.scatter(xip[len(xip)-1]+offset,playerHeight,10,zdir='y',color='purple')

g1.draw(ax,b,p,c)
plt.show()
importlib.reload(plt)
# Out:
# height  0.75
# <module 'matplotlib.pyplot' from '/opt/homebrew/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py'>

# %%
from matplotlib.patches import Rectangle,Circle
from graph import Graph
import matplotlib.pyplot as plt
import numpy as np
import parabolic as para
import importlib
from datetime import datetime, timedelta
import scipy.optimize as optimize
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial.transform import Rotation as R
import math as math
import scipy.optimize as opt

g1 = Graph()
ax = plt.axes(projection="3d")

doex = [.4,.4,.4,.4]
doey = [11,2,2,11]
doez = [9.9,9.9,15.9,15.9]

theta = 1.52
h= 0
k= 0
offset = .4

xParaBounds = 9
yParaBounds = 7

# bellow will draw points where the parabolic mesh should be top left, top right, center, bottom right, and bottom left points
ax.scatter(doex, doey, doez, color='b')
ax.scatter(doex[0],((doey[0]+doey[1])/2),((doez[0]+doez[2])/2),color='b')

guess = (1,1)
#draw hoop, arrays are for x, y location on the graph
backboard=[5,11.5]
xy=[2,10]
#hoop location parameters
circlexy=[2.25,6.5]
x = para.X(0,15)
s = para.parabolic(.3,0,12,x)

b = Rectangle(backboard,3,2.25,fill=False,color='red')
c = Circle((circlexy),radius=2.25,fill=False)
p = Rectangle(xy,9,6,edgecolor='red',facecolor='none')

xi = np.linspace(-5.5, 6.5, 500)
yi = .03*xi**2
yii = (((-xi*math.cos(theta)+yi*math.sin(theta)-h)**2)+k)

ax.plot(yii+offset,-xi+((doey[0]+doey[1])/2),(doez[2]),zdir='z',color='green')

# second plot of the parabola off to the side of the hoop
xii = np.linspace(-5.5,6.5,500)
yii = .03*xii**2
yiii = (((-xi*math.cos(theta)+yi*math.sin(theta)-h)**2)+k)

xiii = np.linspace(-5.5,6.5,500)
yiiii = .03*xii**2
yiiiii = (((-xi*math.cos(theta)+yi*math.sin(theta)-h)**2)+k)

'''
Bellow is where the player (purple dot) is defined in 3d space

'''

xip = np.linspace(0, 10, 500)
yip = .09*-xip**2+12

## player stats
playerHeight = (yip[len(yip)-1]-yip[len(yip)-1]+1.5)/2
print("height ",playerHeight)
ax.scatter(xip[len(xip)-1]+offset,playerHeight,10,zdir='y',color='purple')

#calculate bounce for 1 situation
x1 = circlexy[0]
y1 = circlexy[1]
z1 = 10
x2 = xip[len(xip)-(len(xip))]+offset
y2 = yip[len(yip)-(len(yip))]-2
z2 = 13

# middle point to aim for bounce trajectory
ax.scatter(x2,y2,z2,zdir='z',color='purple')
ax.scatter(x1,y1,z1,zdir='z',color='purple')

x3,y3,z3 = [x2,x1],[y2,y1],[z2,z1]

ax.plot(x3,y3,z3,zdir='z',linestyle='--',color='purple')
ax.plot(xip+offset,yip+1.5,10,zdir='y',color='black')


#X
ax.plot((yiiii+offset)-.5,.5*xiii+((doez[0]+doez[2])/2)-.25,((doey[1])+xParaBounds),zdir='y',color='green')
ax.plot((yiiii+offset)-.5,.5*xiii+((doez[0]+doez[2])/2)-.25,((doey[1])+(xParaBounds-9)),zdir='y',color='green')

#Y
ax.plot((yi+offset)-.5,.765*-xi+((doey[0]+doey[1])/2)+.25,(doez[2]+(yParaBounds-13)),zdir='z',color='green')
ax.plot((yii+offset)-.5,.765*-xi+((doey[0]+doey[1])/2)+.25,(doez[2]),zdir='z',color='green')


g1.draw(ax,b,p,c)
plt.show()
importlib.reload(plt)
# Out:
# height  0.75
# <module 'matplotlib.pyplot' from '/opt/homebrew/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py'>
